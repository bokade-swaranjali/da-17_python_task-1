# %% [markdown]
# # ARC TECHNOLOGIES
# ## DATA ANALYTICS
# ### DA-17
# #### JUPYTER
# ##### CLASS-2
# ###### TUESDAY

# %% [markdown]
# My name is swaranjali bokade.
# I am currently learning Python.
#
# Before this, I have learned Excel and Power bi.

# %% [markdown]
# *I am Swaranjali from DA-17*
#
# _I am Swaranjali from DA-17_

# %% [markdown]
# **da-17 python class**
#
# __da-17 python class__

# %% [markdown]
# ***arc da-17***
#
# ___arc da-17___

# %% [markdown]
# * arc
# * da-17
#     * evening
#     * python
#         * class-2
# * tuesday

# %% [markdown]
# 1. arc
# 2. da-17
#     1. python
#     2. evening
# 3. jupyter

# %% [markdown]
# this is `inline code`.
#
# ```python
# # this is code block
# def hello_world():
#     print("hello from markdown code block!")
#
#     hello_world()

# %% [markdown]
# ```markdown
# https://www.geeksforgeeks.org/python/python-programming-language-tutorial/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > swaranjali
# > bokade
# >> da-17

# %% [markdown]
# ---
#
# ***
#
# ___

# %% [markdown]
# ---

# %% [markdown]
# | h1 | h2 | h3 |
# |----|----|----|
# | r1 c1 | middle | rt. |
# | r2 c1 | python | 333 |

# %% [markdown]
# ___ARC___

# %% [markdown]
# <video controls src="20250617-1600-01.6437908.mp4" title="Title"></video>
